# %% [markdown]
# # 01 Data Exploration
#
# Explore the structure, quality, date range, missing values and duplicates in the Olist datasets.

# %%
from pathlib import Path
import pandas as pd
import numpy as np
